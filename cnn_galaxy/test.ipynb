# %%
from utils import HDF5KeyImageDatasetBalanced
from transform import SimpleResize
from torch.utils.data import DataLoader

idx = 32
cdm_path = f'/n/netscratch/iaifi_lab/Lab/ccuestalazaro/DREAMS/Images/CDM/MW_zooms/box_{idx}/CDM/Galaxy_{idx}.hdf5'
wdm_path = f'/n/netscratch/iaifi_lab/Lab/ccuestalazaro/DREAMS/Images/WDM/MW_zooms/box_{idx}/CDM/Galaxy_{idx}.hdf5'

val_test_transform = SimpleResize(
    size=(256, 256),
    scaling_scheme='tanh'  
)

test_dataset = HDF5KeyImageDatasetBalanced(cdm_path, wdm_path, transform=None)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %%
for idx, batch in enumerate(test_loader):
    imgs, lbls = batch
    if idx==29:
        break

# %%
import numpy as np
import matplotlib.pyplot as plt
i=10

im=np.asarray(imgs[i,0])
# im=np.log1p(im)
# im=np.log1p(im)
# im=np.tanh(im)
# im=np.tanh(im)

im1=np.asarray(imgs[i+1,0])
# im1=np.log1p(im1)
# im1=np.log1p(im1)
# im1=np.tanh(im1)
# im1=np.tanh(im1)

plt.subplot(1,2,1)
plt.imshow(im)
plt.axis('off')
plt.subplot(1,2,2)
plt.imshow(im1)
plt.axis('off')
print(lbls[i],lbls[i+1])
# Out:
# tensor(0.) tensor(1.)

# %%
np.tanh(im1).max()
# Out:
# np.float32(0.55832225)

# %%
import h5py

samples=h5py.File(f'/n/netscratch/iaifi_lab/Lab/ccuestalazaro/DREAMS/Images/CDM/MW_zooms/box_{idx}/CDM/Galaxy_{idx}.hdf5','r')

# %%
samples.keys()
# Out:
# <KeysViewHDF5 ['Mcdm_0', 'Mcdm_1', 'Mcdm_10', 'Mcdm_100', 'Mcdm_101', 'Mcdm_102', 'Mcdm_103', 'Mcdm_104', 'Mcdm_105', 'Mcdm_106', 'Mcdm_107', 'Mcdm_108', 'Mcdm_109', 'Mcdm_11', 'Mcdm_110', 'Mcdm_111', 'Mcdm_112', 'Mcdm_113', 'Mcdm_114', 'Mcdm_115', 'Mcdm_116', 'Mcdm_117', 'Mcdm_118', 'Mcdm_119', 'Mcdm_12', 'Mcdm_120', 'Mcdm_121', 'Mcdm_122', 'Mcdm_123', 'Mcdm_124', 'Mcdm_125', 'Mcdm_126', 'Mcdm_127', 'Mcdm_128', 'Mcdm_129', 'Mcdm_13', 'Mcdm_130', 'Mcdm_131', 'Mcdm_132', 'Mcdm_133', 'Mcdm_134', 'Mcdm_135', 'Mcdm_136', 'Mcdm_137', 'Mcdm_138', 'Mcdm_139', 'Mcdm_14', 'Mcdm_140', 'Mcdm_141', 'Mcdm_142', 'Mcdm_143', 'Mcdm_144', 'Mcdm_145', 'Mcdm_146', 'Mcdm_147', 'Mcdm_148', 'Mcdm_149', 'Mcdm_15', 'Mcdm_150', 'Mcdm_151', 'Mcdm_152', 'Mcdm_153', 'Mcdm_154', 'Mcdm_155', 'Mcdm_156', 'Mcdm_157', 'Mcdm_158', 'Mcdm_159', 'Mcdm_16', 'Mcdm_160', 'Mcdm_161', 'Mcdm_162', 'Mcdm_163', 'Mcdm_164', 'Mcdm_165', 'Mcdm_166', 'Mcdm_167', 'Mcdm_168', 'Mcdm_169', 'Mcdm_17', 'Mcdm_170', 'Mcdm_171', 'Mcdm_172',
# ...

# %%
samples['Mcdm_0']
# Out:
# <HDF5 dataset "Mcdm_0": shape (512, 512), type "<f4">
